# %% [markdown]
# ## Betting Odds Selector

# %%
import sys
path_to_working_script = r'C:\Users\greg\Documents\NFL\bettors_probs\bettors_probs'
sys.path.append(path_to_working_script)

import bettors_probs
import pandas as pd
import pickle
import warnings
import matplotlib.pyplot as plt
import numpy as np

# %%
# load the starting dataframe
path = r'C:\Users\greg\Documents\NFL\bettors_probs\source_data'
file = 'week_7.xlsx'
week7 = pd.read_excel(path+'\\'+file)
file = 'week_10.xlsx'
week10 = pd.read_excel(path+'\\'+file)

# %%
# load the regression model pickle file
file = 'log_reg_spread_model.pkl'
loaded_model = pickle.load(open(path+'\\'+file, 'rb'))

# %%
week10
# Out:
#    Rank     Team  Bettors  Spread
# 0     1    Colts     0.47   -10.0
# 1     2   Saints     0.38   -13.0
# 2     3   Ravens     0.04    -9.5
# 3     4  Packers     0.02    -5.0
# 4     5    Bears     0.01    -2.5
# 5     6   Chiefs     0.01    -3.5
# 6     7    Buccs     0.01    -4.5
# 7     8   Browns     0.01    -3.0
# 8     9     Rams     0.01    -3.5
# 9    10   Giants     0.01    -2.5

# %%
# create a BettorsProbs object, which is just some functions, really
bp = bettors_probs.BettorsProbs()

# %%
# return some prbabilities from spreads
probs = bp.probs_spreads(spreads = week10.Spread, model = loaded_model)

# %%
bet_strength = bp.bet_strength(bettors  = week10.Bettors,
                       spreads = week10.Spread, model = loaded_model)
# Out:
# C:\Users\greg\Documents\NFL\bettors_probs\bettors_probs\bettors_probs.py:77: RuntimeWarning: invalid value encountered in true_divide
#   cond_prob = np.where(rem_bet>0, 1, 0)/rem_bet.sum(axis = 1)[:, np.newaxis]

# %%
week10['Probs'] = probs
week10['Bet_strength'] = bet_strength
week10
# Out:
#    Rank     Team  Bettors  Spread     Probs  Bet_strength
# 0     1    Colts     0.47   -10.0  0.801756      0.915195
# 1     2   Saints     0.38   -13.0  0.864051      1.084588
# 2     3   Ravens     0.04    -9.5  0.789509      1.235516
# 3     4  Packers     0.02    -5.0  0.655635      1.040970
# 4     5    Bears     0.01    -2.5  0.566405      0.912737
# 5     6   Chiefs     0.01    -3.5  0.602976      0.973295
# 6     7    Buccs     0.01    -4.5  0.638431      1.032233
# 7     8   Browns     0.01    -3.0  0.584807      0.943180
# 8     9     Rams     0.01    -3.5  0.602976      0.973295
# 9    10   Giants     0.01    -2.5  0.566405      0.912737

# %% [markdown]
# I would like to calculate the theortical fraction of bettors for a set of probs

# %%
week10.head()
# Out:
#    Rank     Team  Bettors  Spread     Probs  Bet_strength
# 0     1    Colts     0.47   -10.0  0.801756      0.915195
# 1     2   Saints     0.38   -13.0  0.864051      1.084588
# 2     3   Ravens     0.04    -9.5  0.789509      1.235516
# 3     4  Packers     0.02    -5.0  0.655635      1.040970
# 4     5    Bears     0.01    -2.5  0.566405      0.912737

# %%
df = week10.head(2)
df
# Out:
#    Rank    Team  Bettors  Spread     Probs  Bet_strength
# 0     1   Colts     0.47   -10.0  0.801756      0.915195
# 1     2  Saints     0.38   -13.0  0.864051      1.084588

# %%
probs = [.8, .6]
ptc = .72
bettors = [ptc, 1-ptc]
df.Probs = probs
df.Bettors = bettors
bet_strength = bp.bet_strength(bettors  = df.Bettors, probs=df.Probs,
                       model = loaded_model)
df['Bet_strength'] = bet_strength
df
# Out:
# C:\Users\greg\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if __name__ == '__main__':
#    Rank    Team  Bettors  Spread  Probs  Bet_strength
# 0     1   Colts     0.72   -10.0    0.8      1.004444
# 1     2  Saints     0.28   -13.0    0.6      0.988571

# %% [markdown]
# bs 1.1 should go to .7
# bs 1.2 should go to .8
# bs 1.2 should go to .72..
#
# bet_strength does not equate to the percent of Bettors that should be on each bet. . . .
