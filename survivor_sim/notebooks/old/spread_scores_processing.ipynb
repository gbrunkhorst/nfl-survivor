# %% [markdown]
# ## Some work with the spread_scores dataframe and data processing script

# %%
from lastmansim.data_process import load_process_spread_scores as loadit

# %%
spread_scores = loadit()

# %%
loadit(export_csv = True)
# Out:
#      schedule_date  schedule_season schedule_week  schedule_playoff  \
# 0       09/01/1979             1979             1             False
# 1       11/23/1980             1980            12             False
# 2       10/04/1981             1981             5             False
# 3       12/26/1982             1982             8             False
# 4       09/04/1983             1983             1             False
# 5       09/16/1984             1984             3             False
# 6       11/24/1985             1985            12             False
# 7       11/23/1986             1986            12             False
# 8       12/13/1987             1987            10             False
# 9       12/18/1988             1988            16             False
# 10      10/15/1989             1989             6             False
# 11      09/23/1990             1990             3             False
# 12      11/10/1991             1991            11             False
# ...

# %%
spread_scores.head()
# Out:
#   schedule_date  schedule_season schedule_week  schedule_playoff  \
# 0    09/01/1979             1979             1             False
# 1    11/23/1980             1980            12             False
# 2    10/04/1981             1981             5             False
# 3    12/26/1982             1982             8             False
# 4    09/04/1983             1983             1             False
#
#               team_home  score_home  score_away      team_away  \
# 0  Tampa Bay Buccaneers        31.0        16.0  Detroit Lions
# 1  Tampa Bay Buccaneers        10.0        24.0  Detroit Lions
# 2  Tampa Bay Buccaneers        28.0        10.0  Detroit Lions
# 3  Tampa Bay Buccaneers        23.0        21.0  Detroit Lions
# 4  Tampa Bay Buccaneers         0.0        11.0  Detroit Lions
#
#   team_favorite_id  spread_favorite  ... stadium_neutral weather_temperature  \
# 0               TB             -3.0  ...           False                79.0
# ...
